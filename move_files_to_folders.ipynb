# %%
import csv

# %%
import os

# %%
dataset = open('/home/paperspace/data/driver/driver_imgs_list_split.csv', newline = '')

# %%
reader = csv.reader(dataset)

# %%
data = list(reader)

# %%
lines = len(data)

# %%
i = 0

# %%
data[4]
# Out:
# ['p061', 'c0', 'img_94538.jpg']

# %%
for row in data:
    image = row[2]
    state = row[1]
    print('({}/{}) Processing image ({}): {}'.format(i + 1, lines, state, image))
    i += 1
    os.rename('/home/paperspace/data/driver/train/'+ state+ '/'+ image, '/home/paperspace/data/driver/valid/' + state + '/' + image)
# Out:
# (4/4645) Processing image (c0): img_97584.jpg
# (5/4645) Processing image (c0): img_43311.jpg
# (6/4645) Processing image (c0): img_59737.jpg
# (7/4645) Processing image (c0): img_51347.jpg
# (8/4645) Processing image (c0): img_94538.jpg
# (9/4645) Processing image (c0): img_48175.jpg
# (10/4645) Processing image (c0): img_77617.jpg
# (11/4645) Processing image (c0): img_82654.jpg
# (12/4645) Processing image (c0): img_74403.jpg
# (13/4645) Processing image (c0): img_102087.jpg
# (14/4645) Processing image (c0): img_4733.jpg
# (15/4645) Processing image (c0): img_13675.jpg
# (16/4645) Processing image (c0): img_58922.jpg
# (17/4645) Processing image (c0): img_81052.jpg
# (18/4645) Processing image (c0): img_54366.jpg
# (19/4645) Processing image (c0): img_97751.jpg
# (20/4645) Processing image (c0): img_62737.jpg
# (21/4645) Processing image (c0): img_16990.jpg
# (22/4645) Processing image (c0): img_32707.jpg
# (23/4645) Processing image (c0): img_52699.jpg
# ...
